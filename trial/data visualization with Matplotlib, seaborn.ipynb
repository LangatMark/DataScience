# %%
#1.install packages
#pip install pandas
#pip install seaborn
#pip install matplotlib
#pip install numpy

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the 'c:\Users\Hp\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the 'c:\Users\Hp\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
pip install pandas
# Out:
# ...
#
# ...
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the 'c:\Users\Hp\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the 'c:\Users\Hp\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
#import package
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
#A simple dataset
#define data

# %%
x=[10,20,30,40,50]
y=[50,40,30,20,10]

plt.figure(figsize=(5,5))
plt.plot(x,y,linewidth=2.0,color='g',alpha=0.5,marker=('*'))
plt.title('Line Plot')
plt.xlabel('x values')
plt.ylabel('y values')
plt.savefig('line_plot.png')
plt.show()

# %%
plt.figure()

# %%
#from our previous example this is an example of functional programming

x=[10,20,30,40,50]
y=[50,40,30,20,10]

plt.figure(figsize=(5,5))
plt.plot(x,y,linewidth=1.0, linestyle='--',color='r',alpha=0.6,marker=('o'))
plt.title('Line Plot')
plt.xlabel('x values')
plt.ylabel('y values')
plt.legend(['Line'],loc=0)
plt.grid('True')
plt.savefig('line_plot.png')
plt.show()

# %%
fig=plt.figure()

ax=fig.add_axes([0,0,1,1])#figureobject.add_axes([a,b,c,d])a,b refers to the position of origin
ax.set_title('sine wave')
ax.set_xlabel('angle')
ax.set_ylabel('sine')
ax.plot(x,y,linewidth=0.5,linestyle='--',color='r',marker='o',markersize=5)
plt.show()

# %%
#you can also add multiple axes to the figure object as follows
a=np.arange(0,50)
b=a**3
fig=plt.figure()
outer_axes=fig.add_axes([0,0,1,1])
inner_axes=fig.add_axes([0.25,0.5,0.25,0.25])
outer_axes.plot(a,b)

inner_axes.set_xlim(10,20)#sets thhe range on x axis
inner_axes.set_ylim(0,10000)#sets thhe range on y axis
inner_axes.set_title('Zoomed in Version')
inner_axes.plot(a,b)
plt.show()

# %% [markdown]
# #Subplot

# %%
fig, ax=plt.subplots()#figure with a single axes
fig,axs=plt.subplots(2,2)#a figure with a 2 by 2 grid of axes
#a figure with one axes on the left and two on the right:
fig.axs=plt.subplot_mosaic([['left', 'right-top'],['left', 'right-bottom']])

# %%
x=np.linspace(0,2,100)
x
 #creates a numpy array called x with 100 equally spaced values between 0 and 2, inclusive
# Out:
# array([0.        , 0.02020202, 0.04040404, 0.06060606, 0.08080808,
#        0.1010101 , 0.12121212, 0.14141414, 0.16161616, 0.18181818,
#        0.2020202 , 0.22222222, 0.24242424, 0.26262626, 0.28282828,
#        0.3030303 , 0.32323232, 0.34343434, 0.36363636, 0.38383838,
#        0.4040404 , 0.42424242, 0.44444444, 0.46464646, 0.48484848,
#        0.50505051, 0.52525253, 0.54545455, 0.56565657, 0.58585859,
#        0.60606061, 0.62626263, 0.64646465, 0.66666667, 0.68686869,
#        0.70707071, 0.72727273, 0.74747475, 0.76767677, 0.78787879,
#        0.80808081, 0.82828283, 0.84848485, 0.86868687, 0.88888889,
#        0.90909091, 0.92929293, 0.94949495, 0.96969697, 0.98989899,
#        1.01010101, 1.03030303, 1.05050505, 1.07070707, 1.09090909,
#        1.11111111, 1.13131313, 1.15151515, 1.17171717, 1.19191919,
#        1.21212121, 1.23232323, 1.25252525, 1.27272727, 1.29292929,
#        1.31313131, 1.33333333, 1.35353535, 1.37373737, 1.39393939,
# ...

# %%
x=np.linspace(0,2,100)
fig, ax=plt.subplots()

ax.plot(x, x, label='linear')#plot some data on the axes
ax.plot(x, x**2, label='quadratic')#Plot more data on the axes
ax.plot(x, x**3, label='cubic')
ax.plot(x, x**4, label='Fouric')
ax.set_xlabel('x label')
ax.set_title('simple plot')#add a title to the axes
ax.legend(loc=0)#add a legend
plt.show()
